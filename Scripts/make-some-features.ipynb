# %%
import numpy as np
import pandas as pd
import os
import glob
from tqdm import tqdm
import datetime
import gc
import random

# %% [markdown]
# ### Forming Train Set

# %%
data = pd.read_csv("transactions_train.csv", 
                   dtype={'article_id':str}
                  )

# %%
print("All Transactions Date Range: {} to {}".format(data['t_dat'].min(), data['t_dat'].max()))
data["t_dat"] = pd.to_datetime(data["t_dat"])
# Out:
# All Transactions Date Range: 2018-09-20 to 2020-09-22

# %%
articles_df = pd.read_csv('articles.csv', dtype={'article_id':str})
customers_df = pd.read_csv('customers.csv')

# %%
customers_df['fashion_news_frequency'] = customers_df['fashion_news_frequency'].replace('NONE', 'None')
customers_df['age_bucket'] = pd.cut(customers_df['age'].fillna(36), [15, 24, 35, 50, 100], 
                                    labels=['16-24', '25-35', '36-50', '51-100'])

# %%
(articles_df.shape, articles_df.article_id.nunique(), articles_df.garment_group_name.nunique(), 
 articles_df.index_group_name.nunique())
# Out:
# ((105542, 25), 105542, 21, 5)

# %%
articles_df.head(10).T
# Out:
#                                                                     0  \
# article_id                                                 0108775015
# product_code                                                   108775
# prod_name                                                   Strap top
# product_type_no                                                   253
# product_type_name                                            Vest top
# product_group_name                                 Garment Upper body
# graphical_appearance_no                                       1010016
# graphical_appearance_name                                       Solid
# colour_group_code                                                   9
# colour_group_name                                               Black
# perceived_colour_value_id                                           4
# perceived_colour_value_name                                      Dark
# perceived_colour_master_id                                          5
# perceived_colour_master_name                                    Black
# department_no                                                    1676
# department_name                                          Jersey Basic
# index_code                                                          A
# index_name                                                 Ladieswear
# index_group_no                                                      1
# index_group_name                                           Ladieswear
# section_no                                                         16
# section_name                                   Womens Everyday Basics
# garment_group_no                                                 1002
# garment_group_name                                       Jersey Basic
# detail_desc                   Jersey top with narrow shoulder straps.
#
#                                                                     1  \
# article_id                                                 0108775044
# product_code                                                   108775
# prod_name                                                   Strap top
# product_type_no                                                   253
# product_type_name                                            Vest top
# product_group_name                                 Garment Upper body
# graphical_appearance_no                                       1010016
# graphical_appearance_name                                       Solid
# colour_group_code                                                  10
# colour_group_name                                               White
# perceived_colour_value_id                                           3
# perceived_colour_value_name                                     Light
# perceived_colour_master_id                                          9
# perceived_colour_master_name                                    White
# department_no                                                    1676
# department_name                                          Jersey Basic
# index_code                                                          A
# index_name                                                 Ladieswear
# index_group_no                                                      1
# index_group_name                                           Ladieswear
# section_no                                                         16
# section_name                                   Womens Everyday Basics
# garment_group_no                                                 1002
# garment_group_name                                       Jersey Basic
# detail_desc                   Jersey top with narrow shoulder straps.
#
#                                                                     2  \
# article_id                                                 0108775051
# product_code                                                   108775
# prod_name                                               Strap top (1)
# product_type_no                                                   253
# product_type_name                                            Vest top
# product_group_name                                 Garment Upper body
# graphical_appearance_no                                       1010017
# graphical_appearance_name                                      Stripe
# colour_group_code                                                  11
# colour_group_name                                           Off White
# perceived_colour_value_id                                           1
# perceived_colour_value_name                               Dusty Light
# perceived_colour_master_id                                          9
# perceived_colour_master_name                                    White
# department_no                                                    1676
# department_name                                          Jersey Basic
# index_code                                                          A
# index_name                                                 Ladieswear
# index_group_no                                                      1
# index_group_name                                           Ladieswear
# section_no                                                         16
# section_name                                   Womens Everyday Basics
# garment_group_no                                                 1002
# garment_group_name                                       Jersey Basic
# detail_desc                   Jersey top with narrow shoulder straps.
#
#                                                                               3  \
# article_id                                                           0110065001
# product_code                                                             110065
# prod_name                                                     OP T-shirt (Idro)
# product_type_no                                                             306
# product_type_name                                                           Bra
# product_group_name                                                    Underwear
# graphical_appearance_no                                                 1010016
# graphical_appearance_name                                                 Solid
# colour_group_code                                                             9
# colour_group_name                                                         Black
# perceived_colour_value_id                                                     4
# perceived_colour_value_name                                                Dark
# perceived_colour_master_id                                                    5
# perceived_colour_master_name                                              Black
# department_no                                                              1339
# department_name                                                  Clean Lingerie
# index_code                                                                    B
# index_name                                                     Lingeries/Tights
# index_group_no                                                                1
# index_group_name                                                     Ladieswear
# section_no                                                                   61
# section_name                                                    Womens Lingerie
# garment_group_no                                                           1017
# garment_group_name                                            Under-, Nightwear
# detail_desc                   Microfibre T-shirt bra with underwired, moulde...
#
#                                                                               4  \
# article_id                                                           0110065002
# product_code                                                             110065
# prod_name                                                     OP T-shirt (Idro)
# product_type_no                                                             306
# product_type_name                                                           Bra
# product_group_name                                                    Underwear
# graphical_appearance_no                                                 1010016
# graphical_appearance_name                                                 Solid
# colour_group_code                                                            10
# colour_group_name                                                         White
# perceived_colour_value_id                                                     3
# perceived_colour_value_name                                               Light
# perceived_colour_master_id                                                    9
# perceived_colour_master_name                                              White
# department_no                                                              1339
# department_name                                                  Clean Lingerie
# index_code                                                                    B
# index_name                                                     Lingeries/Tights
# index_group_no                                                                1
# index_group_name                                                     Ladieswear
# section_no                                                                   61
# section_name                                                    Womens Lingerie
# garment_group_no                                                           1017
# garment_group_name                                            Under-, Nightwear
# detail_desc                   Microfibre T-shirt bra with underwired, moulde...
#
#                                                                               5  \
# article_id                                                           0110065011
# product_code                                                             110065
# prod_name                                                     OP T-shirt (Idro)
# product_type_no                                                             306
# product_type_name                                                           Bra
# product_group_name                                                    Underwear
# graphical_appearance_no                                                 1010016
# graphical_appearance_name                                                 Solid
# colour_group_code                                                            12
# colour_group_name                                                   Light Beige
# perceived_colour_value_id                                                     1
# perceived_colour_value_name                                         Dusty Light
# perceived_colour_master_id                                                   11
# perceived_colour_master_name                                              Beige
# department_no                                                              1339
# department_name                                                  Clean Lingerie
# index_code                                                                    B
# index_name                                                     Lingeries/Tights
# index_group_no                                                                1
# index_group_name                                                     Ladieswear
# section_no                                                                   61
# section_name                                                    Womens Lingerie
# garment_group_no                                                           1017
# garment_group_name                                            Under-, Nightwear
# detail_desc                   Microfibre T-shirt bra with underwired, moulde...
#
#                                                                               6  \
# article_id                                                           0111565001
# product_code                                                             111565
# prod_name                                                   20 den 1p Stockings
# product_type_no                                                             304
# product_type_name                                              Underwear Tights
# product_group_name                                               Socks & Tights
# graphical_appearance_no                                                 1010016
# graphical_appearance_name                                                 Solid
# colour_group_code                                                             9
# colour_group_name                                                         Black
# perceived_colour_value_id                                                     4
# perceived_colour_value_name                                                Dark
# perceived_colour_master_id                                                    5
# perceived_colour_master_name                                              Black
# department_no                                                              3608
# department_name                                                    Tights basic
# index_code                                                                    B
# index_name                                                     Lingeries/Tights
# index_group_no                                                                1
# index_group_name                                                     Ladieswear
# section_no                                                                   62
# section_name                                     Womens Nightwear, Socks & Tigh
# garment_group_no                                                           1021
# garment_group_name                                             Socks and Tights
# detail_desc                   Semi shiny nylon stockings with a wide, reinfo...
#
#                                                                               7  \
# article_id                                                           0111565003
# product_code                                                             111565
# prod_name                                                   20 den 1p Stockings
# product_type_no                                                             302
# product_type_name                                                         Socks
# product_group_name                                               Socks & Tights
# graphical_appearance_no                                                 1010016
# graphical_appearance_name                                                 Solid
# colour_group_code                                                            13
# colour_group_name                                                         Beige
# perceived_colour_value_id                                                     2
# perceived_colour_value_name                                        Medium Dusty
# perceived_colour_master_id                                                   11
# perceived_colour_master_name                                              Beige
# department_no                                                              3608
# department_name                                                    Tights basic
# index_code                                                                    B
# index_name                                                     Lingeries/Tights
# index_group_no                                                                1
# index_group_name                                                     Ladieswear
# section_no                                                                   62
# section_name                                     Womens Nightwear, Socks & Tigh
# garment_group_no                                                           1021
# garment_group_name                                             Socks and Tights
# detail_desc                   Semi shiny nylon stockings with a wide, reinfo...
#
#                                                                               8  \
# article_id                                                           0111586001
# product_code                                                             111586
# prod_name                                             Shape Up 30 den 1p Tights
# product_type_no                                                             273
# product_type_name                                               Leggings/Tights
# product_group_name                                           Garment Lower body
# graphical_appearance_no                                                 1010016
# graphical_appearance_name                                                 Solid
# colour_group_code                                                             9
# colour_group_name                                                         Black
# perceived_colour_value_id                                                     4
# perceived_colour_value_name                                                Dark
# perceived_colour_master_id                                                    5
# perceived_colour_master_name                                              Black
# department_no                                                              3608
# department_name                                                    Tights basic
# index_code                                                                    B
# index_name                                                     Lingeries/Tights
# index_group_no                                                                1
# index_group_name                                                     Ladieswear
# section_no                                                                   62
# section_name                                     Womens Nightwear, Socks & Tigh
# garment_group_no                                                           1021
# garment_group_name                                             Socks and Tights
# detail_desc                   Tights with built-in support to lift the botto...
#
#                                                                               9
# article_id                                                           0111593001
# product_code                                                             111593
# prod_name                                              Support 40 den 1p Tights
# product_type_no                                                             304
# product_type_name                                              Underwear Tights
# product_group_name                                               Socks & Tights
# graphical_appearance_no                                                 1010016
# graphical_appearance_name                                                 Solid
# colour_group_code                                                             9
# colour_group_name                                                         Black
# perceived_colour_value_id                                                     4
# perceived_colour_value_name                                                Dark
# perceived_colour_master_id                                                    5
# perceived_colour_master_name                                              Black
# department_no                                                              3608
# department_name                                                    Tights basic
# index_code                                                                    B
# index_name                                                     Lingeries/Tights
# index_group_no                                                                1
# index_group_name                                                     Ladieswear
# section_no                                                                   62
# section_name                                     Womens Nightwear, Socks & Tigh
# garment_group_no                                                           1021
# garment_group_name                                             Socks and Tights
# detail_desc                   Semi shiny tights that shape the tummy, thighs...

# %%
articles_df[['index_group_name', 'index_name', 'product_group_name', 
             'product_type_name', 'garment_group_name', 'section_name', 'department_name']].nunique()
# Out:
# index_group_name        5
# index_name             10
# product_group_name     19
# product_type_name     131
# garment_group_name     21
# section_name           56
# department_name       250
# dtype: int64

# %%
articles_df[['index_group_name', 'index_name', 'product_group_name']].drop_duplicates()
# Out:
#        index_group_name                      index_name  product_group_name
# 0            Ladieswear                      Ladieswear  Garment Upper body
# 3            Ladieswear                Lingeries/Tights           Underwear
# 6            Ladieswear                Lingeries/Tights      Socks & Tights
# 8            Ladieswear                Lingeries/Tights  Garment Lower body
# 11        Baby/Children                Baby Sizes 50-98  Garment Upper body
# ...                 ...                             ...                 ...
# 95238     Baby/Children                Baby Sizes 50-98             Unknown
# 95767     Baby/Children  Children Accessories, Swimwear                 Fun
# 97586        Ladieswear                      Ladieswear          Stationery
# 98242     Baby/Children  Children Accessories, Swimwear                Bags
# 100006       Ladieswear              Ladies Accessories                Bags
#
# [99 rows x 3 columns]

# %%
articles_df[articles_df['product_group_name']=='Garment Upper body']['index_name'].unique()
# Out:
# array(['Ladieswear', 'Baby Sizes 50-98', 'Sport',
#        'Children Sizes 134-170', 'Menswear', 'Divided',
#        'Children Sizes 92-140', 'Children Accessories, Swimwear',
#        'Ladies Accessories', 'Lingeries/Tights'], dtype=object)

# %%
customers_df.head().T
# Out:
#                                                                         0  \
# customer_id             00000dbacae5abe5e23885899a1fa44253a17956c6d1c3...
# FN                                                                    NaN
# Active                                                                NaN
# club_member_status                                                 ACTIVE
# fashion_news_frequency                                               None
# age                                                                    49
# postal_code             52043ee2162cf5aa7ee79974281641c6f11a68d276429a...
# age_bucket                                                          36-50
#
#                                                                         1  \
# customer_id             0000423b00ade91418cceaf3b26c6af3dd342b51fd051e...
# FN                                                                    NaN
# Active                                                                NaN
# club_member_status                                                 ACTIVE
# fashion_news_frequency                                               None
# age                                                                    25
# postal_code             2973abc54daa8a5f8ccfe9362140c63247c5eee03f1d93...
# age_bucket                                                          25-35
#
#                                                                         2  \
# customer_id             000058a12d5b43e67d225668fa1f8d618c13dc232df0ca...
# FN                                                                    NaN
# Active                                                                NaN
# club_member_status                                                 ACTIVE
# fashion_news_frequency                                               None
# age                                                                    24
# postal_code             64f17e6a330a85798e4998f62d0930d14db8db1c054af6...
# age_bucket                                                          16-24
#
#                                                                         3  \
# customer_id             00005ca1c9ed5f5146b52ac8639a40ca9d57aeff4d1bd2...
# FN                                                                    NaN
# Active                                                                NaN
# club_member_status                                                 ACTIVE
# fashion_news_frequency                                               None
# age                                                                    54
# postal_code             5d36574f52495e81f019b680c843c443bd343d5ca5b1c2...
# age_bucket                                                         51-100
#
#                                                                         4
# customer_id             00006413d8573cd20ed7128e53b7b13819fe5cfc2d801f...
# FN                                                                      1
# Active                                                                  1
# club_member_status                                                 ACTIVE
# fashion_news_frequency                                          Regularly
# age                                                                    52
# postal_code             25fa5ddee9aac01b35208d01736e57942317d756b32ddd...
# age_bucket                                                         51-100

# %%
data = data.merge(customers_df[['age_bucket', 'customer_id']], on='customer_id', how='left')
data = data.merge(pd.concat([articles_df[['article_id']], 
                             pd.get_dummies(articles_df['index_name'])], axis=1), 
                  on='article_id', how='left')

data['YearWeek'] = data["t_dat"].dt.year.astype(str) + data["t_dat"].dt.week.astype(str)
data['YearWeek'] = data['YearWeek'].astype(int)
# Out:
# /home/tarique/myvenv/lib/python3.6/site-packages/ipykernel_launcher.py:5: FutureWarning: Series.dt.weekofyear and Series.dt.week have been deprecated.  Please use Series.dt.isocalendar().week instead.
#   """

# %%
data.tail().T
# Out:
#                                                                          31788319  \
# t_dat                                                         2020-09-22 00:00:00
# customer_id                     fff2282977442e327b45d8c89afde25617d00124d0f999...
# article_id                                                             0929511001
# price                                                                   0.0593051
# sales_channel_id                                                                2
# age_bucket                                                                  25-35
# Baby Sizes 50-98                                                                0
# Children Accessories, Swimwear                                                  0
# Children Sizes 134-170                                                          0
# Children Sizes 92-140                                                           0
# Divided                                                                         1
# Ladies Accessories                                                              0
# Ladieswear                                                                      0
# Lingeries/Tights                                                                0
# Menswear                                                                        0
# Sport                                                                           0
# YearWeek                                                                   202039
#
#                                                                          31788320  \
# t_dat                                                         2020-09-22 00:00:00
# customer_id                     fff2282977442e327b45d8c89afde25617d00124d0f999...
# article_id                                                             0891322004
# price                                                                   0.0423559
# sales_channel_id                                                                2
# age_bucket                                                                  25-35
# Baby Sizes 50-98                                                                0
# Children Accessories, Swimwear                                                  0
# Children Sizes 134-170                                                          0
# Children Sizes 92-140                                                           0
# Divided                                                                         1
# Ladies Accessories                                                              0
# Ladieswear                                                                      0
# Lingeries/Tights                                                                0
# Menswear                                                                        0
# Sport                                                                           0
# YearWeek                                                                   202039
#
#                                                                          31788321  \
# t_dat                                                         2020-09-22 00:00:00
# customer_id                     fff380805474b287b05cb2a7507b9a013482f7dd0bce0e...
# article_id                                                             0918325001
# price                                                                   0.0432034
# sales_channel_id                                                                1
# age_bucket                                                                 51-100
# Baby Sizes 50-98                                                                0
# Children Accessories, Swimwear                                                  0
# Children Sizes 134-170                                                          0
# Children Sizes 92-140                                                           0
# Divided                                                                         0
# Ladies Accessories                                                              1
# Ladieswear                                                                      0
# Lingeries/Tights                                                                0
# Menswear                                                                        0
# Sport                                                                           0
# YearWeek                                                                   202039
#
#                                                                          31788322  \
# t_dat                                                         2020-09-22 00:00:00
# customer_id                     fff4d3a8b1f3b60af93e78c30a7cb4cf75edaf2590d3e5...
# article_id                                                             0833459002
# price                                                                  0.00676271
# sales_channel_id                                                                1
# age_bucket                                                                  16-24
# Baby Sizes 50-98                                                                0
# Children Accessories, Swimwear                                                  0
# Children Sizes 134-170                                                          0
# Children Sizes 92-140                                                           0
# Divided                                                                         0
# Ladies Accessories                                                              1
# Ladieswear                                                                      0
# Lingeries/Tights                                                                0
# Menswear                                                                        0
# Sport                                                                           0
# YearWeek                                                                   202039
#
#                                                                          31788323
# t_dat                                                         2020-09-22 00:00:00
# customer_id                     fffef3b6b73545df065b521e19f64bf6fe93bfd450ab20...
# article_id                                                             0898573003
# price                                                                   0.0338814
# sales_channel_id                                                                2
# age_bucket                                                                  25-35
# Baby Sizes 50-98                                                                0
# Children Accessories, Swimwear                                                  0
# Children Sizes 134-170                                                          0
# Children Sizes 92-140                                                           0
# Divided                                                                         0
# Ladies Accessories                                                              0
# Ladieswear                                                                      1
# Lingeries/Tights                                                                0
# Menswear                                                                        0
# Sport                                                                           0
# YearWeek                                                                   202039

# %%
article_types = ['Children Accessories, Swimwear', 'Children Sizes 134-170','Children Sizes 92-140', 
                 'Divided', 'Ladies Accessories', 'Ladieswear', 'Lingeries/Tights', 'Menswear', 'Sport']

# %%
# grouping_cols = ['customer_id']
# trn_agg = data.loc[(data["t_dat"] < datetime.datetime(2020,9,16))][article_types+grouping_cols].groupby(grouping_cols).sum().reset_index()
# trn_agg.to_csv('trn_art_agg_cust.csv', index=False)

# del trn_agg

# %%
# gc.collect()

# %%
# trn_agg = data.loc[(data["t_dat"] < datetime.datetime(2020,9,23))][article_types+grouping_cols].groupby(grouping_cols).sum().reset_index()
# trn_agg.to_csv('train_art_agg_cust.csv', index=False)

# del trn_agg

# %%
# gc.collect()

# %%
grouping_cols = ['customer_id', 'YearWeek']

trn_agg = data.loc[(data["t_dat"] < datetime.datetime(2020,9,16))][article_types+grouping_cols].groupby(grouping_cols).sum().reset_index()
trn_agg.to_csv('trn_art_agg_cust_ywk.csv', index=False)

del trn_agg

# %%
gc.collect()
# Out:
# 11

# %%
# trn_agg = data.loc[(data["t_dat"] < datetime.datetime(2020,9,23))][article_types+grouping_cols].groupby(grouping_cols).sum().reset_index()
# trn_agg.to_csv('train_art_agg_cust_ywk.csv', index=False)

# del trn_agg

# %%
# gc.collect()

# %%
grouping_cols = ['customer_id', 'YearWeek', 'age_bucket']

trn_agg = data.loc[(data["t_dat"] < datetime.datetime(2020,9,16))][article_types+grouping_cols].groupby(grouping_cols).sum().reset_index()
trn_agg.to_csv('trn_agg_art_cust_ywk_ab.csv', index=False)

del trn_agg
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# ~/myvenv/lib/python3.6/site-packages/pandas/core/groupby/groupby.py in _agg_general(self, numeric_only, min_count, alias, npfunc)
#    1000             result = self._cython_agg_general(
# -> 1001                 how=alias, alt=npfunc, numeric_only=numeric_only, min_count=min_count,
#    1002             )
#
# ~/myvenv/lib/python3.6/site-packages/pandas/core/groupby/generic.py in _cython_agg_general(self, how, alt, numeric_only, min_count)
#    1023         )
# -> 1024         return self._wrap_agged_blocks(agg_blocks, items=agg_items)
#    1025
#
# ~/myvenv/lib/python3.6/site-packages/pandas/core/groupby/generic.py in _wrap_agged_blocks(self, blocks, items)
#    1756
# -> 1757         return self._reindex_output(result)._convert(datetime=True)
#    1758
#
# ~/myvenv/lib/python3.6/site-packages/pandas/core/groupby/groupby.py in _reindex_output(self, output, fill_value)
#    2726             }
# -> 2727             return output.reindex(**d)
#    2728
#
# ~/myvenv/lib/python3.6/site-packages/pandas/util/_decorators.py in wrapper(*args, **kwargs)
#     308         def wrapper(*args, **kwargs) -> Callable[..., Any]:
# --> 309             return func(*args, **kwargs)
#     310
#
# ~/myvenv/lib/python3.6/site-packages/pandas/core/frame.py in reindex(self, *args, **kwargs)
#    4035         kwargs.pop("labels", None)
# -> 4036         return super().reindex(**kwargs)
#    4037
#
# ~/myvenv/lib/python3.6/site-packages/pandas/core/generic.py in reindex(self, *args, **kwargs)
#    4463         return self._reindex_axes(
# -> 4464             axes, level, limit, tolerance, method, fill_value, copy
#    4465         ).__finalize__(self, method="reindex")
#
# ~/myvenv/lib/python3.6/site-packages/pandas/core/frame.py in _reindex_axes(self, axes, level, limit, tolerance, method, fill_value, copy)
#    3882             frame = frame._reindex_index(
# -> 3883                 index, method, copy, level, fill_value, limit, tolerance
#    3884             )
#
# ~/myvenv/lib/python3.6/site-packages/pandas/core/frame.py in _reindex_index(self, new_index, method, copy, level, fill_value, limit, tolerance)
#    3898         new_index, indexer = self.index.reindex(
# -> 3899             new_index, method=method, level=level, limit=limit, tolerance=tolerance
#    3900         )
#
# ~/myvenv/lib/python3.6/site-packages/pandas/core/indexes/multi.py in reindex(self, target, method, level, limit, tolerance)
#    2315                     indexer = self.get_indexer(
# -> 2316                         target, method=method, limit=limit, tolerance=tolerance
#    2317                     )
#
# ~/myvenv/lib/python3.6/site-packages/pandas/core/indexes/multi.py in get_indexer(self, target, method, limit, tolerance)
#    2469         else:
# -> 2470             indexer = self._engine.get_indexer(target)
#    2471
#
# pandas/_libs/index.pyx in pandas._libs.index.BaseMultiIndexCodesEngine.get_indexer()
#
# pandas/_libs/index.pyx in pandas._libs.index.BaseMultiIndexCodesEngine.get_indexer_no_fill()
#
# pandas/_libs/index.pyx in pandas._libs.index.BaseMultiIndexCodesEngine._extract_level_codes()
#
# ~/myvenv/lib/python3.6/site-packages/pandas/core/indexes/base.py in get_indexer(self, target, method, limit, tolerance)
#    3008
# -> 3009             indexer = self._engine.get_indexer(target._get_engine_target())
#    3010
#
# pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_indexer()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.lookup()
#
# ~/myvenv/lib/python3.6/site-packages/numpy/core/_asarray.py in asarray(a, dtype, order)
#      13
# ---> 14 @set_module('numpy')
#      15 def asarray(a, dtype=None, order=None):
#
# KeyboardInterrupt:
#
# During handling of the above exception, another exception occurred:
#
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-22-2a6f11a674e8> in <module>
#       1 grouping_cols = ['customer_id', 'YearWeek', 'age_bucket']
#       2
# ----> 3 trn_agg = data.loc[(data["t_dat"] < datetime.datetime(2020,9,16))][article_types+grouping_cols].groupby(grouping_cols).sum().reset_index()
#       4 trn_agg.to_csv('trn_agg_art_cust_ywk_ab.csv', index=False)
#       5
#
# ~/myvenv/lib/python3.6/site-packages/pandas/core/groupby/groupby.py in sum(self, numeric_only, min_count)
#    1540     def sum(self, numeric_only: bool = True, min_count: int = 0):
#    1541         return self._agg_general(
# -> 1542             numeric_only=numeric_only, min_count=min_count, alias="add", npfunc=np.sum
#    1543         )
#    1544
#
# ~/myvenv/lib/python3.6/site-packages/pandas/core/groupby/groupby.py in _agg_general(self, numeric_only, min_count, alias, npfunc)
#     999         try:
#    1000             result = self._cython_agg_general(
# -> 1001                 how=alias, alt=npfunc, numeric_only=numeric_only, min_count=min_count,
#    1002             )
#    1003         except DataError:
#
# KeyboardInterrupt:

# %%
# gc.collect()

# %%
# trn_agg = data.loc[(data["t_dat"] < datetime.datetime(2020,9,23))][article_types+grouping_cols].groupby(grouping_cols).sum().reset_index()
# trn_agg.to_csv('train_agg_art_cust_ywk_ab.csv', index=False)

# del trn_agg

# %%
gc.collect()

# %%
# data = data.drop(article_types, axis=1)
# data = data.merge(pd.concat([articles_df[['article_id']], pd.get_dummies(articles_df['product_group_name'])], axis=1), on='article_id', how='left')

# %%
# article_types = ['Accessories', 'Bags', 'Cosmetic', 'Fun', 'Furniture','Garment Full body', 'Garment Lower body', 'Garment Upper body',
#                 'Garment and Shoe care', 'Interior textile', 'Items', 'Nightwear','Shoes', 'Socks & Tights', 'Stationery', 'Swimwear', 'Underwear',
#                 'Underwear/nightwear', 'Unknown']

# %%
# grouping_cols = ['customer_id']
# trn_agg = data.loc[(data["t_dat"] < datetime.datetime(2020,9,16))][article_types+grouping_cols].groupby(grouping_cols).sum().reset_index()
# trn_agg.to_csv('trn_prd_agg_cust.csv', index=False)

# del trn_agg

# %%
# trn_agg = data.loc[(data["t_dat"] < datetime.datetime(2020,9,23))][article_types+grouping_cols].groupby(grouping_cols).sum().reset_index()
# trn_agg.to_csv('train_prd_agg_cust.csv', index=False)

# del trn_agg

# %%
# grouping_cols = ['customer_id', 'YearWeek']

# trn_agg = data.loc[(data["t_dat"] < datetime.datetime(2020,9,16))][article_types+grouping_cols].groupby(grouping_cols).sum().reset_index()
# trn_agg.to_csv('trn_prd_agg_cust_ywk.csv', index=False)

# del trn_agg

# %%
# trn_agg = data.loc[(data["t_dat"] < datetime.datetime(2020,9,23))][article_types+grouping_cols].groupby(grouping_cols).sum().reset_index()
# trn_agg.to_csv('train_prd_agg_cust_ywk.csv', index=False)

# del trn_agg

# %%
# grouping_cols = ['customer_id', 'YearWeek', 'age_bucket']

# trn_agg = data.loc[(data["t_dat"] < datetime.datetime(2020,9,16))][article_types+grouping_cols].groupby(grouping_cols).sum().reset_index()
# trn_agg.to_csv('trn_prd_art_cust_ywk_ab.csv', index=False)

# del trn_agg

# %%
# trn_agg = data.loc[(data["t_dat"] < datetime.datetime(2020,9,23))][article_types+grouping_cols].groupby(grouping_cols).sum().reset_index()
# trn_agg.to_csv('train_prd_art_cust_ywk_ab.csv', index=False)

# del trn_agg

# %%
# def apk(actual, predicted, k=12):
#     if len(predicted)>k:
#         predicted = predicted[:k]

#     score = 0.0
#     num_hits = 0.0

#     for i,p in enumerate(predicted):
#         if p in actual and p not in predicted[:i]:
#             num_hits += 1.0
#             score += num_hits / (i+1.0)

#     if not actual:
#         return 0.0

#     return score / min(len(actual), k)

# def mapk(actual, predicted, k=12):
#     return np.mean([apk(a,p,k) for a,p in zip(actual, predicted)])

# %%
# train0 = data.loc[(data["t_dat"] < datetime.datetime(2020,9,16))]
# train1 = data.loc[(data["t_dat"] < datetime.datetime(2020,9,8))]
# train2 = data.loc[(data["t_dat"] < datetime.datetime(2020,8,31))]
# train3 = data.loc[(data["t_dat"] < datetime.datetime(2020,8,23))]
# train4 = data.loc[(data["t_dat"] < datetime.datetime(2020,8,15))]

# %%
# val0 = data.loc[(data["t_dat"] >= datetime.datetime(2020,9,16)) & (data['t_dat'] < datetime.datetime(2020,9,23))]
# val1 = data.loc[(data["t_dat"] >= datetime.datetime(2020,9,8)) & (data['t_dat'] < datetime.datetime(2020,9,16))]
# val2 = data.loc[(data["t_dat"] >= datetime.datetime(2020,8,31)) & (data['t_dat'] < datetime.datetime(2020,9,8))]
# val3 = data.loc[(data["t_dat"] >= datetime.datetime(2020,8,23)) & (data['t_dat'] < datetime.datetime(2020,8,31))]
# val4 = data.loc[(data["t_dat"] >= datetime.datetime(2020,8,15)) & (data['t_dat'] < datetime.datetime(2020,8,23))]
